# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 750

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bcb7fb5e8f90ad588008de3f278fd373

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]      
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cidreira
# Processing Record 2 of Set 1 | dingle
# Processing Record 3 of Set 1 | kismayo
# Processing Record 4 of Set 1 | castro
# Processing Record 5 of Set 1 | tiksi
# Processing Record 6 of Set 1 | praia
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | broken hill
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | upernavik
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | codrington
# Processing Record 13 of Set 1 | katsuura
# Processing Record 14 of Set 1 | hollins
# Processing Record 15 of Set 1 | norman wells
# Processing Record 16 of Set 1 | adrar
# Processing Record 17 of Set 1 | beian
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | port augusta
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | saucillo
# Processing Record 22 of Set 1 | cabo san lucas
# Processing Record 23 of Set 1 | andra
# Processing Record 24 of Set 1 | erzin
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | meppel
# Processing Record 27 of Set 1 | saint-philippe
# Processing Record 28 of Set 1 | iqaluit
# Processing Record 29 of Set 1 | faanui
# Processing Record 30 of Set 1 | fairbanks
# Processing Record 31 of Set 1 | souillac
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | kavieng
# Processing Record 35 of Set 1 | kodiak
# Processing Record 36 of Set 1 | cabedelo
# Processing Record 37 of Set 1 | imeni poliny osipenko
# Processing Record 38 of Set 1 | rawah
# Processing Record 39 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 1 | luan
# Processing Record 41 of Set 1 | kushnarenkovo
# Processing Record 42 of Set 1 | wanning
# Processing Record 43 of Set 1 | santa rosalia
# Processing Record 44 of Set 1 | cayenne
# Processing Record 45 of Set 1 | severo-kurilsk
# Processing Record 46 of Set 1 | vuktyl
# Processing Record 47 of Set 1 | formoso do araguaia
# City not found. Skipping...
# Processing Record 48 of Set 1 | batemans bay
# Processing Record 49 of Set 1 | lagoa
# Processing Record 50 of Set 1 | hovd
# Processing Record 1 of Set 2 | finnsnes
# Processing Record 2 of Set 2 | haines junction
# Processing Record 3 of Set 2 | aljezur
# Processing Record 4 of Set 2 | new norfolk
# Processing Record 5 of Set 2 | mogadishu
# Processing Record 6 of Set 2 | biscarrosse
# Processing Record 7 of Set 2 | busselton
# Processing Record 8 of Set 2 | chechat
# Processing Record 9 of Set 2 | port hardy
# Processing Record 10 of Set 2 | vagur
# Processing Record 11 of Set 2 | gelibolu
# Processing Record 12 of Set 2 | manokwari
# Processing Record 13 of Set 2 | vila velha
# Processing Record 14 of Set 2 | havre-saint-pierre
# Processing Record 15 of Set 2 | tuktoyaktuk
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 | impfondo
# Processing Record 18 of Set 2 | mitchell
# Processing Record 19 of Set 2 | jieshi
# Processing Record 20 of Set 2 | avarua
# Processing Record 21 of Set 2 | ribeira grande
# Processing Record 22 of Set 2 | kapaa
# Processing Record 23 of Set 2 | georgetown
# Processing Record 24 of Set 2 | jamestown
# Processing Record 25 of Set 2 | khatanga
# Processing Record 26 of Set 2 | cape town
# Processing Record 27 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 2 | necochea
# Processing Record 29 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 2 | marawi
# Processing Record 31 of Set 2 | punta arenas
# Processing Record 32 of Set 2 | visakhapatnam
# Processing Record 33 of Set 2 | nanortalik
# Processing Record 34 of Set 2 | visby
# Processing Record 35 of Set 2 | sitka
# Processing Record 36 of Set 2 | vao
# Processing Record 37 of Set 2 | basco
# Processing Record 38 of Set 2 | namie
# Processing Record 39 of Set 2 | sechura
# Processing Record 40 of Set 2 | pasni
# Processing Record 41 of Set 2 | monroe
# Processing Record 42 of Set 2 | naze
# Processing Record 43 of Set 2 | martapura
# Processing Record 44 of Set 2 | hilo
# Processing Record 45 of Set 2 | saint-francois
# Processing Record 46 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 2 | labuhan
# Processing Record 48 of Set 2 | longyearbyen
# Processing Record 49 of Set 2 | butaritari
# Processing Record 50 of Set 2 | lompoc
# Processing Record 1 of Set 3 | muros
# Processing Record 2 of Set 3 | baykit
# Processing Record 3 of Set 3 | victoria
# Processing Record 4 of Set 3 | imeni telmana
# City not found. Skipping...
# Processing Record 5 of Set 3 | partizanskoye
# Processing Record 6 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 3 | lebu
# Processing Record 8 of Set 3 | santa helena
# Processing Record 9 of Set 3 | maningrida
# Processing Record 10 of Set 3 | limoges
# Processing Record 11 of Set 3 | zyrardow
# Processing Record 12 of Set 3 | tasiilaq
# Processing Record 13 of Set 3 | durant
# Processing Record 14 of Set 3 | laguna
# Processing Record 15 of Set 3 | mar del plata
# Processing Record 16 of Set 3 | clyde river
# Processing Record 17 of Set 3 | kargasok
# Processing Record 18 of Set 3 | mount isa
# Processing Record 19 of Set 3 | esperance
# Processing Record 20 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 3 | yanam
# Processing Record 23 of Set 3 | margate
# Processing Record 24 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 3 | tuatapere
# Processing Record 26 of Set 3 | barrow
# Processing Record 27 of Set 3 | linxia
# Processing Record 28 of Set 3 | kutum
# Processing Record 29 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 3 | sri aman
# Processing Record 31 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 3 | balkhash
# Processing Record 33 of Set 3 | sao filipe
# Processing Record 34 of Set 3 | port elizabeth
# Processing Record 35 of Set 3 | cherskiy
# Processing Record 36 of Set 3 | bac lieu
# Processing Record 37 of Set 3 | acapulco
# Processing Record 38 of Set 3 | tilichiki
# Processing Record 39 of Set 3 | shchuchye
# City not found. Skipping...
# Processing Record 40 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 3 | boa vista
# Processing Record 42 of Set 3 | kruisfontein
# Processing Record 43 of Set 3 | roald
# Processing Record 44 of Set 3 | ulladulla
# Processing Record 45 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 46 of Set 3 | saint-georges
# Processing Record 47 of Set 3 | kangaba
# Processing Record 48 of Set 3 | belz
# Processing Record 49 of Set 3 | zhuhai
# Processing Record 50 of Set 3 | blackwater
# Processing Record 1 of Set 4 | zherdevka
# Processing Record 2 of Set 4 | east london
# Processing Record 3 of Set 4 | verkhneye dubrovo
# Processing Record 4 of Set 4 | ambulu
# Processing Record 5 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 4 | buin
# Processing Record 7 of Set 4 | chokurdakh
# Processing Record 8 of Set 4 | lavrentiya
# Processing Record 9 of Set 4 | puerto ayora
# Processing Record 10 of Set 4 | sobolevo
# Processing Record 11 of Set 4 | barmer
# Processing Record 12 of Set 4 | morehead
# Processing Record 13 of Set 4 | batsfjord
# Processing Record 14 of Set 4 | tual
# Processing Record 15 of Set 4 | arraial do cabo
# Processing Record 16 of Set 4 | bathsheba
# Processing Record 17 of Set 4 | abu samrah
# Processing Record 18 of Set 4 | xinyu
# Processing Record 19 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 4 | te anau
# Processing Record 21 of Set 4 | great yarmouth
# Processing Record 22 of Set 4 | siniscola
# Processing Record 23 of Set 4 | caravelas
# Processing Record 24 of Set 4 | palpa
# Processing Record 25 of Set 4 | winburg
# Processing Record 26 of Set 4 | ishigaki
# Processing Record 27 of Set 4 | ponta do sol
# Processing Record 28 of Set 4 | udachnyy
# Processing Record 29 of Set 4 | vanimo
# Processing Record 30 of Set 4 | kiunga
# Processing Record 31 of Set 4 | dudinka
# Processing Record 32 of Set 4 | puerto baquerizo moreno
# Processing Record 33 of Set 4 | lebyazhye
# Processing Record 34 of Set 4 | panzhihua
# Processing Record 35 of Set 4 | carnarvon
# Processing Record 36 of Set 4 | mahebourg
# Processing Record 37 of Set 4 | paracale
# Processing Record 38 of Set 4 | guerrero negro
# Processing Record 39 of Set 4 | qasigiannguit
# Processing Record 40 of Set 4 | kysyl-syr
# Processing Record 41 of Set 4 | zhenjiang
# Processing Record 42 of Set 4 | raudeberg
# Processing Record 43 of Set 4 | northam
# Processing Record 44 of Set 4 | vaini
# Processing Record 45 of Set 4 | bethel
# Processing Record 46 of Set 4 | hermanus
# Processing Record 47 of Set 4 | solikamsk
# Processing Record 48 of Set 4 | chuy
# Processing Record 49 of Set 4 | nikolskoye
# Processing Record 50 of Set 4 | presidencia roque saenz pena
# Processing Record 1 of Set 5 | yakeshi
# Processing Record 2 of Set 5 | tari
# Processing Record 3 of Set 5 | husavik
# Processing Record 4 of Set 5 | bilma
# Processing Record 5 of Set 5 | la ronge
# Processing Record 6 of Set 5 | merauke
# Processing Record 7 of Set 5 | ballina
# Processing Record 8 of Set 5 | half moon bay
# Processing Record 9 of Set 5 | port hedland
# Processing Record 10 of Set 5 | bredasdorp
# Processing Record 11 of Set 5 | fengrun
# Processing Record 12 of Set 5 | itarema
# Processing Record 13 of Set 5 | hasaki
# Processing Record 14 of Set 5 | poum
# Processing Record 15 of Set 5 | talaya
# Processing Record 16 of Set 5 | sala
# Processing Record 17 of Set 5 | sohag
# Processing Record 18 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 19 of Set 5 | lahaina
# Processing Record 20 of Set 5 | port blair
# Processing Record 21 of Set 5 | saldanha
# Processing Record 22 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 23 of Set 5 | san pedro de ycuamandiyu
# Processing Record 24 of Set 5 | morondava
# Processing Record 25 of Set 5 | mackay
# Processing Record 26 of Set 5 | kashi
# Processing Record 27 of Set 5 | pavlovsk
# Processing Record 28 of Set 5 | bontang
# Processing Record 29 of Set 5 | touros
# Processing Record 30 of Set 5 | saskylakh
# Processing Record 31 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 32 of Set 5 | canaries
# Processing Record 33 of Set 5 | isangel
# Processing Record 34 of Set 5 | fortuna
# Processing Record 35 of Set 5 | hofn
# Processing Record 36 of Set 5 | babstovo
# Processing Record 37 of Set 5 | axim
# Processing Record 38 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 39 of Set 5 | moree
# Processing Record 40 of Set 5 | bambous virieux
# Processing Record 41 of Set 5 | qaanaaq
# Processing Record 42 of Set 5 | henties bay
# Processing Record 43 of Set 5 | waingapu
# Processing Record 44 of Set 5 | chernyanka
# Processing Record 45 of Set 5 | arroyo
# Processing Record 46 of Set 5 | rudnichnyy
# Processing Record 47 of Set 5 | shingu
# Processing Record 48 of Set 5 | burnie
# Processing Record 49 of Set 5 | flin flon
# Processing Record 50 of Set 5 | boende
# Processing Record 1 of Set 6 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 2 of Set 6 | hami
# Processing Record 3 of Set 6 | ketchikan
# Processing Record 4 of Set 6 | thompson
# Processing Record 5 of Set 6 | hithadhoo
# Processing Record 6 of Set 6 | hamilton
# Processing Record 7 of Set 6 | urucara
# Processing Record 8 of Set 6 | trairi
# Processing Record 9 of Set 6 | kuznetsk
# Processing Record 10 of Set 6 | uaua
# Processing Record 11 of Set 6 | ahipara
# Processing Record 12 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 6 | kirando
# Processing Record 14 of Set 6 | dori
# Processing Record 15 of Set 6 | cap malheureux
# Processing Record 16 of Set 6 | geraldton
# Processing Record 17 of Set 6 | mount gambier
# Processing Record 18 of Set 6 | bitung
# Processing Record 19 of Set 6 | luderitz
# Processing Record 20 of Set 6 | traverse city
# Processing Record 21 of Set 6 | gizo
# Processing Record 22 of Set 6 | aklavik
# Processing Record 23 of Set 6 | constitucion
# Processing Record 24 of Set 6 | saint george
# Processing Record 25 of Set 6 | berlevag
# Processing Record 26 of Set 6 | dikson
# Processing Record 27 of Set 6 | grand gaube
# Processing Record 28 of Set 6 | nome
# Processing Record 29 of Set 6 | kabanjahe
# Processing Record 30 of Set 6 | jerantut
# Processing Record 31 of Set 6 | kribi
# Processing Record 32 of Set 6 | ayagoz
# Processing Record 33 of Set 6 | coihaique
# Processing Record 34 of Set 6 | vestmanna
# Processing Record 35 of Set 6 | luwuk
# Processing Record 36 of Set 6 | bubaque
# Processing Record 37 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 6 | pevek
# Processing Record 39 of Set 6 | barranca
# Processing Record 40 of Set 6 | plettenberg bay
# Processing Record 41 of Set 6 | cockburn town
# Processing Record 42 of Set 6 | wickede
# Processing Record 43 of Set 6 | medyn
# Processing Record 44 of Set 6 | magadan
# Processing Record 45 of Set 6 | sabha
# Processing Record 46 of Set 6 | mayumba
# Processing Record 47 of Set 6 | dharmanagar
# Processing Record 48 of Set 6 | fenelon falls
# Processing Record 49 of Set 6 | otradnoye
# Processing Record 50 of Set 6 | los llanos de aridane
# Processing Record 1 of Set 7 | kahului
# Processing Record 2 of Set 7 | vostok
# Processing Record 3 of Set 7 | pahrump
# Processing Record 4 of Set 7 | wangaratta
# Processing Record 5 of Set 7 | narsaq
# Processing Record 6 of Set 7 | broome
# Processing Record 7 of Set 7 | galle
# Processing Record 8 of Set 7 | berberati
# Processing Record 9 of Set 7 | beringovskiy
# Processing Record 10 of Set 7 | lasa
# Processing Record 11 of Set 7 | pangnirtung
# Processing Record 12 of Set 7 | bandarbeyla
# Processing Record 13 of Set 7 | os
# City not found. Skipping...
# Processing Record 14 of Set 7 | rawson
# Processing Record 15 of Set 7 | kaitangata
# Processing Record 16 of Set 7 | bengkulu
# Processing Record 17 of Set 7 | namibe
# Processing Record 18 of Set 7 | fairview
# Processing Record 19 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 7 | mezen
# Processing Record 21 of Set 7 | san matias
# Processing Record 22 of Set 7 | kloulklubed
# Processing Record 23 of Set 7 | dok kham tai
# Processing Record 24 of Set 7 | hobyo
# Processing Record 25 of Set 7 | bayangol
# Processing Record 26 of Set 7 | barabai
# Processing Record 27 of Set 7 | nioro
# Processing Record 28 of Set 7 | bow island
# Processing Record 29 of Set 7 | fare
# Processing Record 30 of Set 7 | pavlodar
# Processing Record 31 of Set 7 | bloemhof
# Processing Record 32 of Set 7 | vila franca do campo
# Processing Record 33 of Set 7 | mandalgovi
# Processing Record 34 of Set 7 | quesnel
# Processing Record 35 of Set 7 | antofagasta
# Processing Record 36 of Set 7 | provideniya
# Processing Record 37 of Set 7 | dzhebariki-khaya
# Processing Record 38 of Set 7 | kuybysheve
# Processing Record 39 of Set 7 | lodja
# Processing Record 40 of Set 7 | leningradskiy
# Processing Record 41 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 42 of Set 7 | lillooet
# Processing Record 43 of Set 7 | horsham
# Processing Record 44 of Set 7 | churapcha
# Processing Record 45 of Set 7 | arlit
# Processing Record 46 of Set 7 | ribeira brava
# Processing Record 47 of Set 7 | togur
# Processing Record 48 of Set 7 | batagay-alyta
# Processing Record 49 of Set 7 | vila nova de milfontes
# Processing Record 50 of Set 7 | saint-joseph
# Processing Record 1 of Set 8 | sorong
# Processing Record 2 of Set 8 | salinopolis
# Processing Record 3 of Set 8 | tommot
# Processing Record 4 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 5 of Set 8 | burns lake
# Processing Record 6 of Set 8 | pacific grove
# Processing Record 7 of Set 8 | ust-omchug
# Processing Record 8 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 9 of Set 8 | el prat de llobregat
# Processing Record 10 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 11 of Set 8 | nizhniy tsasuchey
# Processing Record 12 of Set 8 | lakeville
# Processing Record 13 of Set 8 | fethiye
# Processing Record 14 of Set 8 | ternate
# Processing Record 15 of Set 8 | klaksvik
# Processing Record 16 of Set 8 | sur
# Processing Record 17 of Set 8 | ilulissat
# Processing Record 18 of Set 8 | kamyzyak
# Processing Record 19 of Set 8 | mahenge
# Processing Record 20 of Set 8 | salalah
# Processing Record 21 of Set 8 | krasnovishersk
# Processing Record 22 of Set 8 | hay river
# Processing Record 23 of Set 8 | carutapera
# Processing Record 24 of Set 8 | sinnamary
# Processing Record 25 of Set 8 | portland
# Processing Record 26 of Set 8 | srednekolymsk
# Processing Record 27 of Set 8 | wawa
# Processing Record 28 of Set 8 | praia da vitoria
# Processing Record 29 of Set 8 | atar
# Processing Record 30 of Set 8 | orange
# Processing Record 31 of Set 8 | taunggyi
# Processing Record 32 of Set 8 | ariquemes
# Processing Record 33 of Set 8 | beidao
# Processing Record 34 of Set 8 | namatanai
# Processing Record 35 of Set 8 | port lincoln
# Processing Record 36 of Set 8 | komsomolskiy
# Processing Record 37 of Set 8 | sovetskaya gavan
# Processing Record 38 of Set 8 | cacheu
# Processing Record 39 of Set 8 | bingol
# Processing Record 40 of Set 8 | yarensk
# Processing Record 41 of Set 8 | san jose
# Processing Record 42 of Set 8 | puerto narino
# Processing Record 43 of Set 8 | rio grande
# Processing Record 44 of Set 8 | luocheng
# Processing Record 45 of Set 8 | huambo
# Processing Record 46 of Set 8 | butembo
# Processing Record 47 of Set 8 | mbanza-ngungu
# Processing Record 48 of Set 8 | bonthe
# Processing Record 49 of Set 8 | anadyr
# Processing Record 50 of Set 8 | meulaboh
# Processing Record 1 of Set 9 | rudnya
# Processing Record 2 of Set 9 | huangchuan
# Processing Record 3 of Set 9 | kiboga
# Processing Record 4 of Set 9 | eureka
# Processing Record 5 of Set 9 | gornozavodsk
# Processing Record 6 of Set 9 | corner brook
# Processing Record 7 of Set 9 | san cristobal
# Processing Record 8 of Set 9 | tessalit
# Processing Record 9 of Set 9 | causapscal
# Processing Record 10 of Set 9 | ulaangom
# Processing Record 11 of Set 9 | graaff-reinet
# Processing Record 12 of Set 9 | palmer
# Processing Record 13 of Set 9 | ruteng
# Processing Record 14 of Set 9 | umm lajj
# Processing Record 15 of Set 9 | hoquiam
# Processing Record 16 of Set 9 | barauna
# Processing Record 17 of Set 9 | gimbi
# Processing Record 18 of Set 9 | torbay
# Processing Record 19 of Set 9 | springfield
# Processing Record 20 of Set 9 | tarma
# Processing Record 21 of Set 9 | hailar
# Processing Record 22 of Set 9 | tecoanapa
# Processing Record 23 of Set 9 | mischii
# Processing Record 24 of Set 9 | san carlos
# Processing Record 25 of Set 9 | dukstas
# Processing Record 26 of Set 9 | pozo colorado
# Processing Record 27 of Set 9 | savannakhet
# Processing Record 28 of Set 9 | dubinino
# Processing Record 29 of Set 9 | soe
# Processing Record 30 of Set 9 | monrovia
# Processing Record 31 of Set 9 | karakol
# Processing Record 32 of Set 9 | lorengau
# Processing Record 33 of Set 9 | tandlianwala
# Processing Record 34 of Set 9 | karratha
# Processing Record 35 of Set 9 | shubarkuduk
# Processing Record 36 of Set 9 | karamay
# City not found. Skipping...
# Processing Record 37 of Set 9 | beloha
# Processing Record 38 of Set 9 | terrak
# Processing Record 39 of Set 9 | boguchany
# Processing Record 40 of Set 9 | bulgan
# Processing Record 41 of Set 9 | marrakesh
# Processing Record 42 of Set 9 | jinchang
# Processing Record 43 of Set 9 | avera
# Processing Record 44 of Set 9 | pisco
# Processing Record 45 of Set 9 | yelizovo
# Processing Record 46 of Set 9 | tucumcari
# Processing Record 47 of Set 9 | rypefjord
# Processing Record 48 of Set 9 | blagoveshchensk
# Processing Record 49 of Set 9 | walvis bay
# Processing Record 50 of Set 9 | bredy
# Processing Record 1 of Set 10 | novobirilyussy
# Processing Record 2 of Set 10 | nyahururu
# Processing Record 3 of Set 10 | niquero
# Processing Record 4 of Set 10 | porto novo
# Processing Record 5 of Set 10 | marsh harbour
# Processing Record 6 of Set 10 | kasongo-lunda
# Processing Record 7 of Set 10 | nelson bay
# Processing Record 8 of Set 10 | kupang
# Processing Record 9 of Set 10 | koslan
# Processing Record 10 of Set 10 | belaya gora
# Processing Record 11 of Set 10 | moanda
# Processing Record 12 of Set 10 | raga
# Processing Record 13 of Set 10 | libertador general san martin
# Processing Record 14 of Set 10 | dmitrov
# Processing Record 15 of Set 10 | puri
# Processing Record 16 of Set 10 | ostend
# Processing Record 17 of Set 10 | kijang
# Processing Record 18 of Set 10 | cairns
# Processing Record 19 of Set 10 | tateyama
# Processing Record 20 of Set 10 | burla
# Processing Record 21 of Set 10 | tirur
# Processing Record 22 of Set 10 | tahoua
# Processing Record 23 of Set 10 | along
# Processing Record 24 of Set 10 | shache
# Processing Record 25 of Set 10 | burgos
# Processing Record 26 of Set 10 | ancud
# Processing Record 27 of Set 10 | sars
# Processing Record 28 of Set 10 | byron bay
# Processing Record 29 of Set 10 | pitimbu
# Processing Record 30 of Set 10 | san policarpo
# Processing Record 31 of Set 10 | male
# Processing Record 32 of Set 10 | gogapur
# Processing Record 33 of Set 10 | bahia honda
# Processing Record 34 of Set 10 | pocone
# Processing Record 35 of Set 10 | grindavik
# Processing Record 36 of Set 10 | menongue
# Processing Record 37 of Set 10 | asau
# Processing Record 38 of Set 10 | egvekinot
# Processing Record 39 of Set 10 | santa isabel
# Processing Record 40 of Set 10 | paignton
# Processing Record 41 of Set 10 | ati
# Processing Record 42 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 43 of Set 10 | aksu
# Processing Record 44 of Set 10 | ozernovskiy
# Processing Record 45 of Set 10 | galdar
# Processing Record 46 of Set 10 | port macquarie
# Processing Record 47 of Set 10 | tautira
# Processing Record 48 of Set 10 | dosso
# Processing Record 49 of Set 10 | maracaibo
# Processing Record 50 of Set 10 | abnub
# Processing Record 1 of Set 11 | vestmannaeyjar
# Processing Record 2 of Set 11 | palizada
# Processing Record 3 of Set 11 | dunedin
# Processing Record 4 of Set 11 | gogrial
# Processing Record 5 of Set 11 | jingdezhen
# Processing Record 6 of Set 11 | airai
# Processing Record 7 of Set 11 | willowmore
# Processing Record 8 of Set 11 | changji
# Processing Record 9 of Set 11 | sakaiminato
# Processing Record 10 of Set 11 | padang
# Processing Record 11 of Set 11 | jojoima
# Processing Record 12 of Set 11 | nadadores
# Processing Record 13 of Set 11 | itoman
# Processing Record 14 of Set 11 | novopokrovka
# Processing Record 15 of Set 11 | oussouye
# Processing Record 16 of Set 11 | barra mansa
# Processing Record 17 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 18 of Set 11 | burica
# City not found. Skipping...
# Processing Record 19 of Set 11 | parnarama
# Processing Record 20 of Set 11 | verkh-usugli
# Processing Record 21 of Set 11 | zhanakorgan
# Processing Record 22 of Set 11 | duz
# City not found. Skipping...
# Processing Record 23 of Set 11 | alta floresta
# Processing Record 24 of Set 11 | colon
# Processing Record 25 of Set 11 | huaquechula
# Processing Record 26 of Set 11 | yeppoon
# Processing Record 27 of Set 11 | wladyslawowo
# Processing Record 28 of Set 11 | blythe
# Processing Record 29 of Set 11 | prieska
# Processing Record 30 of Set 11 | pathein
# Processing Record 31 of Set 11 | izhma
# Processing Record 32 of Set 11 | ogaminana
# Processing Record 33 of Set 11 | ucluelet
# Processing Record 34 of Set 11 | lata
# Processing Record 35 of Set 11 | nhulunbuy
# Processing Record 36 of Set 11 | talnakh
# Processing Record 37 of Set 11 | bilibino
# Processing Record 38 of Set 11 | moroni
# Processing Record 39 of Set 11 | inyonga
# Processing Record 40 of Set 11 | svetlaya
# Processing Record 41 of Set 11 | kudahuvadhoo
# Processing Record 42 of Set 11 | snyder
# Processing Record 43 of Set 11 | lazaro cardenas
# Processing Record 44 of Set 11 | sioux lookout
# Processing Record 45 of Set 11 | ostrovnoy
# Processing Record 46 of Set 11 | videira
# Processing Record 47 of Set 11 | domna
# Processing Record 48 of Set 11 | palu
# Processing Record 49 of Set 11 | mizdah
# Processing Record 50 of Set 11 | shelopugino
# Processing Record 1 of Set 12 | tatsuno
# Processing Record 2 of Set 12 | savannah bight
# Processing Record 3 of Set 12 | buritizeiro
# Processing Record 4 of Set 12 | tolga
# Processing Record 5 of Set 12 | santa cruz
# Processing Record 6 of Set 12 | leiyang
# Processing Record 7 of Set 12 | chifeng
# Processing Record 8 of Set 12 | mitsamiouli
# Processing Record 9 of Set 12 | mahibadhoo
# Processing Record 10 of Set 12 | ladario
# Processing Record 11 of Set 12 | norilsk
# Processing Record 12 of Set 12 | curup
# Processing Record 13 of Set 12 | ouadda
# Processing Record 14 of Set 12 | port-gentil
# Processing Record 15 of Set 12 | chikoy
# City not found. Skipping...
# Processing Record 16 of Set 12 | kaeo
# Processing Record 17 of Set 12 | imbituba
# Processing Record 18 of Set 12 | alofi
# Processing Record 19 of Set 12 | coos bay
# Processing Record 20 of Set 12 | maumere
# Processing Record 21 of Set 12 | nevelsk
# Processing Record 22 of Set 12 | sabang
# Processing Record 23 of Set 12 | catalina
# Processing Record 24 of Set 12 | zhanaozen
# Processing Record 25 of Set 12 | am timan
# Processing Record 26 of Set 12 | derzhavinsk
# Processing Record 27 of Set 12 | qaqortoq
# Processing Record 28 of Set 12 | pangkalanbuun
# Processing Record 29 of Set 12 | san ramon de la nueva oran
# Processing Record 30 of Set 12 | harper
# Processing Record 31 of Set 12 | yerbogachen
# Processing Record 32 of Set 12 | shelburne
# Processing Record 33 of Set 12 | talcahuano
# Processing Record 34 of Set 12 | shimoda
# Processing Record 35 of Set 12 | batouri
# Processing Record 36 of Set 12 | peabiru
# Processing Record 37 of Set 12 | alice springs
# Processing Record 38 of Set 12 | yulara
# Processing Record 39 of Set 12 | dresden
# Processing Record 40 of Set 12 | sansai
# City not found. Skipping...
# Processing Record 41 of Set 12 | fiumicino
# Processing Record 42 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 12 | barcelos
# Processing Record 44 of Set 12 | bossangoa
# Processing Record 45 of Set 12 | saint anthony
# Processing Record 46 of Set 12 | nantucket
# Processing Record 47 of Set 12 | mandan
# Processing Record 48 of Set 12 | saint-augustin
# Processing Record 49 of Set 12 | teluk nibung
# Processing Record 50 of Set 12 | ponta delgada
# Processing Record 1 of Set 13 | comrat
# Processing Record 2 of Set 13 | puerto ayacucho
# Processing Record 3 of Set 13 | peterhead
# Processing Record 4 of Set 13 | zatoka
# Processing Record 5 of Set 13 | kokoda
# Processing Record 6 of Set 13 | bundaberg
# Processing Record 7 of Set 13 | gwadar
# Processing Record 8 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 13 | praya
# Processing Record 10 of Set 13 | swan hill
# Processing Record 11 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 13 | zyryanka
# Processing Record 13 of Set 13 | bourne
# Processing Record 14 of Set 13 | tromso
# Processing Record 15 of Set 13 | muhos
# Processing Record 16 of Set 13 | sabirabad
# Processing Record 17 of Set 13 | stekolnyy
# City not found. Skipping...
# Processing Record 18 of Set 13 | jagadhri
# Processing Record 19 of Set 13 | sistranda
# Processing Record 20 of Set 13 | myrtle beach
# Processing Record 21 of Set 13 | kyra
# Processing Record 22 of Set 13 | saint pete beach
# Processing Record 23 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 13 | erdenet
# Processing Record 25 of Set 13 | juneau
# Processing Record 26 of Set 13 | hashtrud
# Processing Record 27 of Set 13 | monte plata
# Processing Record 28 of Set 13 | filadelfia
# Processing Record 29 of Set 13 | novyy urengoy
# Processing Record 30 of Set 13 | evinayong
# Processing Record 31 of Set 13 | aiken
# Processing Record 32 of Set 13 | munchenbuchsee
# Processing Record 33 of Set 13 | sao joao da barra
# Processing Record 34 of Set 13 | el doncello
# Processing Record 35 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 36 of Set 13 | korla
# Processing Record 37 of Set 13 | ginir
# Processing Record 38 of Set 13 | kenora
# Processing Record 39 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 40 of Set 13 | altonia
# City not found. Skipping...
# Processing Record 41 of Set 13 | bucerias
# Processing Record 42 of Set 13 | liuli
# Processing Record 43 of Set 13 | pingxiang
# Processing Record 44 of Set 13 | teya
# Processing Record 45 of Set 13 | pucallpa
# Processing Record 46 of Set 13 | kawana waters
# City not found. Skipping...
# Processing Record 47 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 48 of Set 13 | jiuquan
# Processing Record 49 of Set 13 | shahr-e babak
# Processing Record 50 of Set 13 | mehamn
# Processing Record 1 of Set 14 | tabas
# Processing Record 2 of Set 14 | goderich
# Processing Record 3 of Set 14 | mutoko
# Processing Record 4 of Set 14 | pochutla
# Processing Record 5 of Set 14 | ifanadiana
# Processing Record 6 of Set 14 | coihueco
# Processing Record 7 of Set 14 | bangui
# Processing Record 8 of Set 14 | maceio
# Processing Record 9 of Set 14 | zhigansk
# Processing Record 10 of Set 14 | innisfail
# Processing Record 11 of Set 14 | yagodnoye
# Processing Record 12 of Set 14 | camopi
# Processing Record 13 of Set 14 | dumai
# Processing Record 14 of Set 14 | inawashiro
# Processing Record 15 of Set 14 | ouesso
# Processing Record 16 of Set 14 | nishihara
# Processing Record 17 of Set 14 | svetlogorsk
# Processing Record 18 of Set 14 | lydenburg
# Processing Record 19 of Set 14 | dhidhdhoo
# Processing Record 20 of Set 14 | dormidontovka
# Processing Record 21 of Set 14 | boca do acre
# Processing Record 22 of Set 14 | gayny
# Processing Record 23 of Set 14 | koshurnikovo
# Processing Record 24 of Set 14 | zharkent
# Processing Record 25 of Set 14 | miyako
# Processing Record 26 of Set 14 | huarmey
# Processing Record 27 of Set 14 | inhambane
# Processing Record 28 of Set 14 | resistencia
# Processing Record 29 of Set 14 | ratnagiri
# Processing Record 30 of Set 14 | giengen
# City not found. Skipping...
# Processing Record 31 of Set 14 | lubawa
# Processing Record 32 of Set 14 | bitaogan
# Processing Record 33 of Set 14 | ladybrand
# Processing Record 34 of Set 14 | redmond
# Processing Record 35 of Set 14 | phan thiet
# Processing Record 36 of Set 14 | cape canaveral
# Processing Record 37 of Set 14 | lakes entrance
# Processing Record 38 of Set 14 | saint-leu
# Processing Record 39 of Set 14 | bakchar
# Processing Record 40 of Set 14 | izumo
# Processing Record 41 of Set 14 | kavaratti
# Processing Record 42 of Set 14 | vanavara
# Processing Record 43 of Set 14 | noumea
# Processing Record 44 of Set 14 | dicabisagan
# Processing Record 45 of Set 14 | qingdao
# Processing Record 46 of Set 14 | zhuanghe
# Processing Record 47 of Set 14 | yumen
# Processing Record 48 of Set 14 | suzaka
# Processing Record 49 of Set 14 | tura
# Processing Record 50 of Set 14 | piriyapatna
# Processing Record 1 of Set 15 | alekseyevka
# Processing Record 2 of Set 15 | jimo
# Processing Record 3 of Set 15 | corinto
# Processing Record 4 of Set 15 | eydhafushi
# Processing Record 5 of Set 15 | araceli
# Processing Record 6 of Set 15 | brandon
# Processing Record 7 of Set 15 | gavrilovka vtoraya
# Processing Record 8 of Set 15 | neya
# Processing Record 9 of Set 15 | nuuk
# Processing Record 10 of Set 15 | sitrah
# Processing Record 11 of Set 15 | pangoa
# Processing Record 12 of Set 15 | salihli
# Processing Record 13 of Set 15 | nabire
# Processing Record 14 of Set 15 | noshiro
# Processing Record 15 of Set 15 | ponnani
# Processing Record 16 of Set 15 | ostuni
# Processing Record 17 of Set 15 | azul
# Processing Record 18 of Set 15 | ontario
# Processing Record 19 of Set 15 | nagorsk
# Processing Record 20 of Set 15 | perrenjas
# City not found. Skipping...
# Processing Record 21 of Set 15 | buraydah
# Processing Record 22 of Set 15 | lima
# Processing Record 23 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 24 of Set 15 | ahtopol
# Processing Record 25 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 15 | dovolnoye
# Processing Record 27 of Set 15 | birjand
# Processing Record 28 of Set 15 | marystown
# Processing Record 29 of Set 15 | panguna
# Processing Record 30 of Set 15 | dauphin
# Processing Record 31 of Set 15 | vardo
# Processing Record 32 of Set 15 | guigue
# Processing Record 33 of Set 15 | mayor pablo lagerenza
# Processing Record 34 of Set 15 | cape coast
# Processing Record 35 of Set 15 | kirakira
# Processing Record 36 of Set 15 | alugan
# Processing Record 37 of Set 15 | santa isabel do rio negro
# Processing Record 38 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 39 of Set 15 | araouane
# Processing Record 40 of Set 15 | latung
# Processing Record 41 of Set 15 | mudgee
# Processing Record 42 of Set 15 | altamira
# Processing Record 43 of Set 15 | san francisco del mar
# Processing Record 44 of Set 15 | kathu
# Processing Record 45 of Set 15 | kodinsk
# Processing Record 46 of Set 15 | trebisacce
# Processing Record 47 of Set 15 | zhangjiakou
# Processing Record 48 of Set 15 | catalao
# Processing Record 49 of Set 15 | nova londrina
# Processing Record 50 of Set 15 | casablanca
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 699

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Cidreira      BR -30.1811  -50.2056     63.57        92         100
# 1       Dingle      PH  10.9995  122.6711     75.97        90         100
# 2      Kismayo      SO  -0.3582   42.5454     77.36        83          11
# 3       Castro      BR -24.7911  -50.0119     65.89        86         100
# 4        Tiksi      RU  71.6872  128.8694     12.07        87         100
# 5        Praia      CV  14.9215  -23.5087     79.34        73           0
# 6       Atuona      PF  -9.8000 -139.0333     76.89        75          28
# 7  Broken Hill      AU -31.9500  141.4333     61.93        46         100
# 8  Yellowknife      CA  62.4560 -114.3525     45.12        70          20
# 9    Upernavik      GL  72.7868  -56.1549     37.83        96         100
#
#    Wind Speed Current Description
# 0       20.98     overcast clouds
# 1        8.86     overcast clouds
# 2       13.00          few clouds
# 3        5.46     overcast clouds
# 4       15.12     overcast clouds
# 5       18.41           clear sky
# 6       14.76    scattered clouds
# 7       13.98     overcast clouds
# 8       13.80          few clouds
# 9       30.91          light rain

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Cidreira      BR -30.1811  -50.2056     63.57        92         100
# 1       Dingle      PH  10.9995  122.6711     75.97        90         100
# 2      Kismayo      SO  -0.3582   42.5454     77.36        83          11
# 3       Castro      BR -24.7911  -50.0119     65.89        86         100
# 4        Tiksi      RU  71.6872  128.8694     12.07        87         100
# 5        Praia      CV  14.9215  -23.5087     79.34        73           0
# 6       Atuona      PF  -9.8000 -139.0333     76.89        75          28
# 7  Broken Hill      AU -31.9500  141.4333     61.93        46         100
# 8  Yellowknife      CA  62.4560 -114.3525     45.12        70          20
# 9    Upernavik      GL  72.7868  -56.1549     37.83        96         100
#
#    Wind Speed Current Description
# 0       20.98     overcast clouds
# 1        8.86     overcast clouds
# 2       13.00          few clouds
# 3        5.46     overcast clouds
# 4       15.12     overcast clouds
# 5       18.41           clear sky
# 6       14.76    scattered clouds
# 7       13.98     overcast clouds
# 8       13.80          few clouds
# 9       30.91          light rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 
                    'Cloudiness', 'Wind Speed', 'Current Description']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Cidreira      BR -30.1811  -50.2056     63.57        92         100
# 1       Dingle      PH  10.9995  122.6711     75.97        90         100
# 2      Kismayo      SO  -0.3582   42.5454     77.36        83          11
# 3       Castro      BR -24.7911  -50.0119     65.89        86         100
# 4        Tiksi      RU  71.6872  128.8694     12.07        87         100
# 5        Praia      CV  14.9215  -23.5087     79.34        73           0
# 6       Atuona      PF  -9.8000 -139.0333     76.89        75          28
# 7  Broken Hill      AU -31.9500  141.4333     61.93        46         100
# 8  Yellowknife      CA  62.4560 -114.3525     45.12        70          20
# 9    Upernavik      GL  72.7868  -56.1549     37.83        96         100
#
#    Wind Speed Current Description
# 0       20.98     overcast clouds
# 1        8.86     overcast clouds
# 2       13.00          few clouds
# 3        5.46     overcast clouds
# 4       15.12     overcast clouds
# 5       18.41           clear sky
# 6       14.76    scattered clouds
# 7       13.98     overcast clouds
# 8       13.80          few clouds
# 9       30.91          light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes.value_counts()
# Out:
# float64    4
# object     3
# int64      2
# dtype: int64

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = 'challenge_data/WeatherPy_database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv("WeatherPy_Database.csv", index_label="City_ID")
